# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf
from IPython.display import display,HTML

# %%
#carga de archivo
DATA=pd.read_csv('airbnb.csv', encoding= 'ISO-8859-1')
DATA
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data=DATA.copy()

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                    0
# name                                  3
# host_id                               0
# host_name                             7
# neighbourhood_group               21669
# neighbourhood                         6
# latitude                              4
# longitude                             2
# room_type                             9
# price                                 1
# minimum_nights                        1
# number_of_reviews                     4
# last_review                        3990
# reviews_per_month                  3990
# calculated_host_listings_count        2
# availability_365                      4
# number_of_reviews_ltm                 4
# dtype: int64

# %%
data["host_name"] =data["host_name"].fillna(method="bfill") 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data["neighbourhood"] =data["neighbourhood"].fillna(method="ffill") 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data["latitude"]=data["latitude"].fillna(round(data["latitude"].mean(),1))
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
#Sustituir valores nulos con mediana
data["longitude"]=data["longitude"].fillna(round(data["longitude"].median(),1))
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data["room_type"] =data["room_type"].fillna("Private room") 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data["price"]=data["price"].fillna(round(data["price"].mean(),1))
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data["minimum_nights"]= data["minimum_nights"].fillna(1) 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data["number_of_reviews"]= data["number_of_reviews"].fillna(0) 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                    0
# name                                  3
# host_id                               0
# host_name                             0
# neighbourhood_group               21669
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        3990
# reviews_per_month                  3990
# calculated_host_listings_count        2
# availability_365                      4
# number_of_reviews_ltm                 4
# dtype: int64

# %%
data["last_review"] =data["last_review"].fillna("31/12/2022") 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data["reviews_per_month"]=data["reviews_per_month"].fillna(round(data["reviews_per_month"].mean(),1))
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data["calculated_host_listings_count"]= data["calculated_host_listings_count"].fillna(1) 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data["availability_365"] =data["availability_365"].fillna(method="bfill") 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                    0
# name                                  3
# host_id                               0
# host_name                             0
# neighbourhood_group               21669
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                           0
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 4
# dtype: int64

# %%
data["number_of_reviews_ltm"] =data["number_of_reviews_ltm"].fillna(method="bfill") 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# ...

# %%
data["neighbourhood_group"] =data["neighbourhood_group"].fillna("Desconocido") 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
data["name"] =data["name"].fillna("Desconocido") 
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64

# %%
#Outliers

# %%
La=data["latitude"]
Limite_Superior= La.mean() + 3*La.std()
Limite_Inferior= La.mean() - 3*La.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 22.0250088466136
# Limite inferior permitido 16.795011725586317

# %%
outliers= data[(La>Limite_Superior)|(La<Limite_Inferior)]
outliers
# Out:
#                id                                 name    host_id  \
# 12741  46757982.0  Residencia Master Suite con Terraza  375169008
# 21665  22107097.0        GREAT & cozy flat in Satelite  387195495
#
#          host_name neighbourhood_group   neighbourhood   latitude  longitude  \
# 12741  Residencias         Desconocido  Benito JuÃ¡rez   99.39291  -99.17623
# 21665      Daniela         Desconocido    Azcapotzalco  119.50787  -99.22067
#
#              room_type   price  minimum_nights  number_of_reviews last_review  \
# 12741  Entire home/apt  3678.0             2.0                0.0  31/12/2022
# 21665  Entire home/apt   897.0             2.0              107.0  07/02/2022
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 12741               1.60                            25.0             337.0
# 21665               1.97                            11.0             314.0
#
#        number_of_reviews_ltm
# 12741                    0.0
# ...

# %%
#Obtenemos datos limpios
data_clean= data[(La<=Limite_Superior)&(La>=Limite_Inferior)]
data_clean
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21663  4.588272e+07  Big/nice/YOGUI room, in relax & sure neighborhood
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["latitude"]) 
plt.title("Outliers de latitude")
plt.show() #dibujamos el diagrama

# %%
Lo=data["longitude"]
Limite_Superior= Lo.mean() + 3*La.std()
Limite_Inferior= Lo.mean() - 3*La.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido -96.54981591125846
# Limite inferior permitido -101.77981303228574

# %%
outliers= data[(Lo>Limite_Superior)|(Lo<Limite_Inferior)]
outliers
# Out:
#                id                                      name    host_id  \
# 12003  45519073.0  Spacious 3BR/3.5BATH in heart of Condesa    2593419
# 12009  45454474.0      Bonito departamento cerca del Ãngel  303864680
#
#          host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 12003        Katie         Desconocido   CuauhtÃ©moc  19.41882 -399.17598
# 12009  Leidi Laura         Desconocido   CuauhtÃ©moc  19.42738  299.16998
#
#              room_type   price  minimum_nights  number_of_reviews last_review  \
# 12003  Entire home/apt  3040.0             3.0               48.0  22/05/2022
# 12009  Entire home/apt  2670.0             1.0                6.0  09/01/2022
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 12003               2.65                             1.0             165.0
# 12009               0.28                             8.0             359.0
#
#        number_of_reviews_ltm
# 12003                   44.0
# ...

# %%
data_clean= data[(Lo<=Limite_Superior)&(Lo>=Limite_Inferior)]
data_clean
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["longitude"]) 
plt.title("Outliers de longitude")
plt.show() #dibujamos el diagrama

# %%
p=data["price"]
Limite_Superior= Lo.mean() + 3*La.std()
Limite_Inferior= Lo.mean() - 3*La.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido -96.54981591125846
# Limite inferior permitido -101.77981303228574

# %%
outliers= data[(p>Limite_Superior)|(p<Limite_Inferior)]
outliers
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
data_clean= data[(p<=Limite_Superior)&(p>=Limite_Inferior)]
data_clean
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm]
# Index: []

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["price"]) 
plt.title("Outliers de price")
plt.show() #dibujamos el diagrama

# %%
mn=data["minimum_nights"]
Limite_Superior= mn.mean() + 3*mn.std()
Limite_Inferior= mn.mean() - 3*mn.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 85.28175780845893
# Limite inferior permitido -75.59916977947745

# %%
outliers= data[(mn>Limite_Superior)|(mn<Limite_Inferior)]
outliers
# Out:
#                id                                             name    host_id  \
# 0        826691.0                  Suite 7 - Suites Condesa Mexico    4326326
# 73      1187817.0                  Suite 1 - Suites Condesa Mexico    4326326
# 169      525618.0                 Beautiful Colonia Roma apartment    2566629
# 183     1798108.0  Near park Mexico. Brilliant and renovated flat!    1595855
# 326     4604145.0                  Suite 3 - Suites Condesa Mexico    4326326
# ...           ...                                              ...        ...
# 21317  48096905.0                                   Se renta Suite  387846773
# 21350  23741236.0                     Interlomas Perfect Apartment   10358425
# 21527  17732363.0                         DEPARTAMENTOS AMUEBLADOS  120918514
# 21545  31946858.0    Bonito cuarto privado para dama en La Florida  146368828
# 21567  36036705.0       Departamento Remodelado en Renta Echegaray  271110724
#
# ...

# %%
data_clean= data[(mn<=Limite_Superior)&(mn>=Limite_Inferior)]
data_clean
# Out:
#                  id                                               name  \
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# 5      8.287140e+05             Apartment with Internet & 2 cable TV's
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["minimum_nights"]) 
plt.title("Outliers de minimum_nights")
plt.show() #dibujamos el diagrama

# %%
nr=data["number_of_reviews"]
Limite_Superior= nr.mean() + 3*nr.std()
Limite_Inferior= nr.mean() - 3*nr.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 200.14693399059885
# Limite inferior permitido -136.9106978929478

# %%
outliers= data[(nr>Limite_Superior)|(nr<Limite_Inferior)]
outliers
# Out:
#                id                                               name  \
# 23       883511.0  Cozy House with Roofterrace group 29 pax Cente...
# 31       165772.0       BEST 4BR 4 BH HOUSE IN S. MIGUEL CHAPULTEPEC
# 32      2083241.0  Condesa Apartment in 1920s Landmarked Art Nouv...
# 33       939721.0       Radiant Apartment with Terrace in Roma Norte
# 35       997247.0                NEW! HISTORIC BUILDING -BEST STREET
# ...           ...                                                ...
# 16325  52769775.0  Charming & Cozy 1BR Apt | 2 Rooftops+Gym+B/Center
# 16326  52769810.0  2BR Apt w/Balcony |Rooftop-FirePit+Best Views+Gym
# 16327  52769824.0  Wonderful 2BR Apt |Polanco|2 Rooftops+Gym+B/Ce...
# 16328  52769833.0  Cute & Intimate Apt | Gym+2 Rooftops+Fire Pit+...
# 16919  53418457.0           Ayenda Terraza 158, Double Standard Room
#
#          host_id    host_name neighbourhood_group   neighbourhood   latitude  \
# ...

# %%
data_clean= data[(nr<=Limite_Superior)&(nr>=Limite_Inferior)]
data_clean
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["number_of_reviews"]) 
plt.title("Outliers de number_of_reviews")
plt.show() #dibujamos el diagrama

# %%
rm=data["reviews_per_month"]
Limite_Superior= rm.mean() + 3*rm.std()
Limite_Inferior= rm.mean() - 3*rm.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 7.048517946936302
# Limite inferior permitido -3.8713090309734053

# %%
outliers= data[(rm>Limite_Superior)|(rm<Limite_Inferior)]
outliers
# Out:
#                  id                                               name  \
# 1488   1.339804e+07  Depa privado para visitar monumentos emblemÃ¡t...
# 1674   1.415008e+07                              5 min to CDMX airport
# 1675   1.415013e+07                              5 min to CDMX airport
# 1785   1.432096e+07      Trendy and cozy apartment at CondesaÂ´s heart
# 2247   1.702510e+07     Bedroom near the airport of the city of Mexico
# ...             ...                                                ...
# 20226  6.270000e+17                      Danni's sunny & spacious Home
# 20232  6.290000e+17                       Apt Monet | Polanco | Antara
# 20255  6.310000e+17  Loft Suite JuÃ¡rez Reforma a tres cuadras del ...
# 20352  6.300000e+17  302â
#  LA MEJOR UBICACIÃN ! REFORMA / CHAPULT...
# 20427  6.330000e+17  Executive Apt |Great Location|Gym+B/Center+Roo...
#
#          host_id   host_name neighbourhood_group        neighbourhood  \
# ...

# %%
data_clean= data[(rm<=Limite_Superior)&(rm>=Limite_Inferior)]
data_clean
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["reviews_per_month"]) 
plt.title("Outliers de reviews_per_month")
plt.show() #dibujamos el diagrama

# %%
av=data["availability_365"]
Limite_Superior= av.mean() + 3*av.std()
Limite_Inferior= av.mean() - 3*av.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 612.4014586334399
# Limite inferior permitido -125.45042259116755

# %%
outliers= data[(av>Limite_Superior)|(av<Limite_Inferior)]
outliers
# Out:
#            id                                 name   host_id host_name  \
# 15  2056638.0  Amplio y luminoso loft en CoyoacÃ¡n  10531228     Maria
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 15         Desconocido     CoyoacÃ¡n  19.35353  -99.16299  Entire home/apt
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 15  1602.0             1.0               21.0  24/06/2018                0.2
#
#     calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 15                             3.0            1290.0                    0.0

# %%
data_clean= data[(av<=Limite_Superior)&(av>=Limite_Inferior)]
data_clean
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["availability_365"]) 
plt.title("Outliers de availability_365")
plt.show() #dibujamos el diagrama

# %%
#Punto 5

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 La 0.75
La=data["latitude"]

percentile25=La.quantile(0.25) #Q1
percentile75=La.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 19.507845000000003
# Limite inferior permitido 19.303884999999994

# %%
#Encontramos Ouliers
outliers_iqr= data[(La>Limite_Superior_iqr)|(La<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#                id                                               name  \
# 96       329776.0                                 HabitaciÃ³n Verde.
# 194      609594.0                                House in Xochimilco
# 206     1920070.0                  Mountain Oasis surrender by trees
# 213     1945351.0             Private room. Near COLMEX, UPN, FLACSO
# 277     3506037.0                          SUITES BOSQUES MEDICA SUR
# ...           ...                                                ...
# 21638  52622073.0  Departamento Viveros del Lago.\nEnfrente de la...
# 21646  33914551.0                                          Cozy depa
# 21652  39023239.0           Recamara privada cerca del metro Rosario
# 21656  16928664.0              Hermosa habitaciÃ³n con baÃ±o privado
# 21665  22107097.0                      GREAT & cozy flat in Satelite
#
#          host_id  host_name neighbourhood_group neighbourhood   latitude  \
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= data[(La<=Limite_Superior_iqr)&(La>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21663  4.588272e+07  Big/nice/YOGUI room, in relax & sure neighborhood
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["latitude"]) 
plt.title("Outliers de latitude")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 La 0.75
Lo=data["longitude"]

percentile25=Lo.quantile(0.25) #Q1
percentile75=Lo.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido -99.112705
# Limite inferior permitido -99.22274499999997

# %%
#Encontramos Ouliers
outliers_iqr= data[(Lo>Limite_Superior_iqr)|(Lo<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#                  id                                               name  \
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 6      1.551198e+07                                 La casa de Abraham
# 7      3.477645e+07  â
#  The attic â
#  Panoramic garden 10 min Citi...
# 8      4.576710e+07  BONITO DEPARTAMENTO NUEVO  LOMAS DE  TECAMACHALCO
# ...             ...                                                ...
# 21663  4.588272e+07  Big/nice/YOGUI room, in relax & sure neighborhood
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id           host_name neighbourhood_group  \
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= data[(Lo<=Limite_Superior_iqr)&(Lo>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#                id                                               name  \
# 0        826691.0                    Suite 7 - Suites Condesa Mexico
# 3        826760.0                   Suite 12 - Suites Condesa Mexico
# 4         44616.0                                  CONDESA HAUS  B&B
# 5        828714.0             Apartment with Internet & 2 cable TV's
# 9        832805.0      ROOMS CASA INDIGO WITH TERRACE AT CITY CENTER
# ...           ...                                                ...
# 21646  33914551.0                                          Cozy depa
# 21648  34205914.0  casa con mucha seguridad y tranquilidad en nau...
# 21652  39023239.0           Recamara privada cerca del metro Rosario
# 21656  16928664.0              Hermosa habitaciÃ³n con baÃ±o privado
# 21665  22107097.0                      GREAT & cozy flat in Satelite
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["longitude"]) 
plt.title("Outliers de longitude")
plt.show() #dibujamos el diagrama

# %%
p=data["price"]

percentile25=p.quantile(0.25) #Q1
percentile75=p.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 2960.0
# Limite inferior permitido -976.0

# %%
#Encontramos Ouliers
outliers_iqr= data[(p>Limite_Superior_iqr)|(p<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#                  id                                               name  \
# 1      3.579700e+04                                        Villa Dante
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# 28     1.070780e+05                                 NEW  DESIGNER LOFT
# 31     1.657720e+05       BEST 4BR 4 BH HOUSE IN S. MIGUEL CHAPULTEPEC
# 39     2.093036e+06                Departamento 2 dormitorios x Antara
# ...             ...                                                ...
# 21540  1.377077e+07                   Estudiantes parada Tec AnÃ¡huac.
# 21567  3.603670e+07         Departamento Remodelado en Renta Echegaray
# 21598  5.450000e+17  Cheerful 4 bedroom residence in nice neighborhood
# 21609  6.490000e+17         4 habitaciones 11 camas en casa compartida
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= data[(p<=Limite_Superior_iqr)&(p>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 5      8.287140e+05             Apartment with Internet & 2 cable TV's
# 6      1.551198e+07                                 La casa de Abraham
# ...             ...                                                ...
# 21663  4.588272e+07  Big/nice/YOGUI room, in relax & sure neighborhood
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
#
#          host_id           host_name neighbourhood_group  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["price"]) 
plt.title("Outliers de price")
plt.show() #dibujamos el diagrama

# %%
mn=data["minimum_nights"]

percentile25=p.quantile(0.25) #Q1
percentile75=p.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 2960.0
# Limite inferior permitido -976.0

# %%
#Encontramos Ouliers
outliers_iqr= data[(mn>Limite_Superior_iqr)|(mn<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm]
# Index: []

# %%
data_clean_iqr= data[(mn<=Limite_Superior_iqr)&(mn>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["minimum_nights"]) 
plt.title("Outliers de minimum_nights")
plt.show() #dibujamos el diagrama

# %%
nr=data["number_of_reviews"]

percentile25=p.quantile(0.25) #Q1
percentile75=p.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 2960.0
# Limite inferior permitido -976.0

# %%
outliers_iqr= data[(nr>Limite_Superior_iqr)|(nr<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm]
# Index: []

# %%
data_clean_iqr= data[(nr<=Limite_Superior_iqr)&(nr>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["number_of_reviews"]) 
plt.title("Outliers de number_of_reviews")
plt.show() #dibujamos el diagrama

# %%
rm=data["reviews_per_month"]

percentile25=p.quantile(0.25) #Q1
percentile75=p.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 2960.0
# Limite inferior permitido -976.0

# %%
outliers_iqr= data[(rm>Limite_Superior_iqr)|(rm<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm]
# Index: []

# %%
data_clean_iqr= data[(rm<=Limite_Superior_iqr)&(rm>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["reviews_per_month"]) 
plt.title("Outliers de reviews_per_month")
plt.show() #dibujamos el diagrama

# %%
av=data["availability_365"]

percentile25=p.quantile(0.25) #Q1
percentile75=p.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 2960.0
# Limite inferior permitido -976.0

# %%
outliers_iqr= data[(av>Limite_Superior_iqr)|(av<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm]
# Index: []

# %%
data_clean_iqr= data[(av<=Limite_Superior_iqr)&(av>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["availability_365"]) 
plt.title("Outliers de availability_365")
plt.show() #dibujamos el diagrama
